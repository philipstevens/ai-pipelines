# %% [markdown]
# # 🧪 LLM Fine-Tuning Workflow
# This notebook demonstrates how to run a domain-specific fine-tuning using the **AI Pipelines** framework.
#
# You can run this directly in Google Colab or locally after cloning the repository.

# %%
# ✅ Setup environment
# !pip install -r ../../env.yml  # or manually install required packages

# %%
# 🧠 Run fine-tuning
# !python ../../pipelines/llm_finetuning/scripts/run_finetune.py

# %% [markdown]
# ## 📊 Evaluate Results
# After training completes, you can evaluate and generate a report.

# %%
# !python ../../pipelines/llm_finetuning/scripts/run_eval.py

# %% [markdown]
# ## 📦 Generate Client Delivery Report
# Creates both Markdown and PDF versions using the template.

# %%
# !python ../../scripts/generate_client_report.py
